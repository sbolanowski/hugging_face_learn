# %% [markdown]
# # Set Up

# %% [markdown]
# ## Only Once

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo

# !sudo apt-get update
# !apt-get install swig cmake ffmpeg
# !apt install python-opengl xvfb

# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# !pip3 install pyvirtualdisplay

import os
os.kill(os.getpid(), 9)
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-90qvdghu
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-90qvdghu
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit ab4aadb57c6c42abcf1016318c2bebe35c4c1270
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.7.0 (from rl_zoo3==2.7.0)
#   Downloading sb3_contrib-2.7.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.7.0) (1.2.0)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.7.0)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.7.0) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.7.0) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.7.0)
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.7.0) (6.0.2)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.7.0)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.7.0)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (0.34.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (1.1.3)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.7.0)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.7.0)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (2.0.42)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.7.0) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable_baselines3<3.0,>=2.7.0 (from sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.7.0) (2.19.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.7.0) (1.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (1.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.7.0) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.11/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.7.0) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.7.0) (3.2.3)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.6.0+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.0.2)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 18.3 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 10.6 MB/s eta 0:00:00
# Downloading sb3_contrib-2.7.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 9.7 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 27.6 MB/s eta 0:00:00
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 20.7 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.7 MB/s eta 0:00:00
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.7.0-py3-none-any.whl size=78020 sha256=fd3d21c4a341246a726802b11874ce2ecc637046c8c7ae7435e6cb114dfcdeda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i4nu746t/wheels/79/a7/a1/afc7c6c739a99c02b2cba585d219d453a80ab2bff20fb6526f
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mbstrdecoder, colorlog, typepy, shimmy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, alembic, optuna, nvidia-cusolver-cu12, huggingface_sb3, DataProperty, tabledata, stable_baselines3, sb3_contrib, pytablewriter, rl_zoo3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed DataProperty-1.1.0 alembic-1.16.4 colorlog-6.9.0 huggingface_sb3-3.0 mbstrdecoder-1.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 optuna-4.4.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.7.0 sb3_contrib-2.7.0 shimmy-2.0.0 stable_baselines3-2.7.0 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,775 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,168 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,207 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,518 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,270 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,103 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,575 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,290 kB]
# Fetched 32.3 MB in 3s (10.9 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (819 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package python-opengl
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.11/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.11.2)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.11/dist-packages (1.2.0)
# WARNING: gymnasium 1.2.0 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %% [markdown]
# ---

# %% [markdown]
# # Imports

# %%
# Hugging Face
from huggingface_hub import notebook_login

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ---

# %% [markdown]
# # Space Invaders
#
#
#
# ## Bibliography
#
# For further information on the Space Invaders environment, please refer to the official documentation provided by ALE:
#
# - [Space Invaders - Documentation](https://ale.farama.org/environments/space_invaders/)
#
# ---

# %% [markdown]
# ## Hyperparameter Config

# %%
def create_yml():
    config = {
        'SpaceInvadersNoFrameskip-v4': {
            'env_wrapper': [
                'stable_baselines3.common.atari_wrappers.AtariWrapper'
            ],
            'frame_stack': 4,
            'policy': 'CnnPolicy',
            'n_timesteps': 1e6,
            'buffer_size': 100000,
            'learning_rate': 1e-4,
            'batch_size': 32,
            'learning_starts': 100000,
            'target_update_interval': 1000,
            'train_freq': 4,
            'gradient_steps': 1,
            'exploration_fraction': 0.1,
            'exploration_final_eps': 0.01,
            'optimize_memory_usage': False
        }
    }

    with open('dqn.yml', 'w') as archivo_yaml:
        yaml.dump(config, archivo_yaml, default_flow_style=False)

    print("Created hyperparameter config file...")

create_yml()
# Out:
# Created hyperparameter config file...

# %% [markdown]
# ---
#
# ## Training

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2580     |
# |    fps              | 278      |
# |    time_elapsed     | 1952     |
# |    total_timesteps  | 544235   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 111058   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2584     |
# |    fps              | 278      |
# |    time_elapsed     | 1955     |
# |    total_timesteps  | 545147   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0447   |
# |    n_updates        | 111286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2588     |
# |    fps              | 278      |
# |    time_elapsed     | 1959     |
# |    total_timesteps  | 546013   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 111503   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2592     |
# |    fps              | 278      |
# |    time_elapsed     | 1961     |
# |    total_timesteps  | 546760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 111689   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2596     |
# |    fps              | 278      |
# |    time_elapsed     | 1965     |
# |    total_timesteps  | 547824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 111955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 278      |
# |    time_elapsed     | 1971     |
# |    total_timesteps  | 549221   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 112305   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2604     |
# |    fps              | 278      |
# |    time_elapsed     | 1973     |
# |    total_timesteps  | 549927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 112481   |
# ----------------------------------
# Eval num_timesteps=550000, episode_reward=399.00 +/- 74.46
# Episode length: 3146.60 +/- 668.73
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.15e+03 |
# |    mean_reward      | 399      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 550000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 112499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2608     |
# |    fps              | 277      |
# |    time_elapsed     | 1984     |
# |    total_timesteps  | 550636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.057    |
# |    n_updates        | 112658   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2612     |
# |    fps              | 277      |
# |    time_elapsed     | 1990     |
# |    total_timesteps  | 552427   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 113106   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2616     |
# |    fps              | 277      |
# |    time_elapsed     | 1993     |
# |    total_timesteps  | 553090   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 113272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2620     |
# |    fps              | 277      |
# |    time_elapsed     | 1997     |
# |    total_timesteps  | 554263   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 113565   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2624     |
# |    fps              | 277      |
# |    time_elapsed     | 2001     |
# |    total_timesteps  | 555289   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 113822   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2628     |
# |    fps              | 277      |
# |    time_elapsed     | 2005     |
# |    total_timesteps  | 556353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0541   |
# |    n_updates        | 114088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2632     |
# |    fps              | 277      |
# |    time_elapsed     | 2009     |
# |    total_timesteps  | 557247   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 114311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2636     |
# |    fps              | 277      |
# |    time_elapsed     | 2014     |
# |    total_timesteps  | 558746   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 114686   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2640     |
# |    fps              | 277      |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 559559   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 114889   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 437      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2644     |
# |    fps              | 277      |
# |    time_elapsed     | 2021     |
# |    total_timesteps  | 560451   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 115112   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2648     |
# |    fps              | 277      |
# |    time_elapsed     | 2025     |
# |    total_timesteps  | 561744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 115435   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2652     |
# |    fps              | 277      |
# |    time_elapsed     | 2028     |
# |    total_timesteps  | 562436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 115608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2656     |
# |    fps              | 277      |
# |    time_elapsed     | 2033     |
# |    total_timesteps  | 563767   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 115941   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2660     |
# |    fps              | 277      |
# |    time_elapsed     | 2038     |
# |    total_timesteps  | 565184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 116295   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2664     |
# |    fps              | 277      |
# |    time_elapsed     | 2041     |
# |    total_timesteps  | 566033   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00977  |
# |    n_updates        | 116508   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2668     |
# |    fps              | 277      |
# |    time_elapsed     | 2046     |
# |    total_timesteps  | 567368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 116841   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2672     |
# |    fps              | 277      |
# |    time_elapsed     | 2050     |
# |    total_timesteps  | 568395   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0462   |
# |    n_updates        | 117098   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2676     |
# |    fps              | 277      |
# |    time_elapsed     | 2056     |
# |    total_timesteps  | 570109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 117527   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 277      |
# |    time_elapsed     | 2061     |
# |    total_timesteps  | 571572   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00936  |
# |    n_updates        | 117892   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 277      |
# |    time_elapsed     | 2066     |
# |    total_timesteps  | 572835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0592   |
# |    n_updates        | 118208   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 277      |
# |    time_elapsed     | 2069     |
# |    total_timesteps  | 573577   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.063    |
# |    n_updates        | 118394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 277      |
# |    time_elapsed     | 2072     |
# |    total_timesteps  | 574342   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 118585   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=283.00 +/- 183.76
# Episode length: 2103.00 +/- 660.62
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.1e+03  |
# |    mean_reward      | 283      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 118749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 276      |
# |    time_elapsed     | 2084     |
# |    total_timesteps  | 575968   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 118991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 276      |
# |    time_elapsed     | 2087     |
# |    total_timesteps  | 576825   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0363   |
# |    n_updates        | 119206   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 276      |
# |    time_elapsed     | 2091     |
# |    total_timesteps  | 578077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 119519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 276      |
# |    time_elapsed     | 2095     |
# |    total_timesteps  | 578942   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 119735   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 276      |
# |    time_elapsed     | 2099     |
# |    total_timesteps  | 580256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 120063   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 276      |
# |    time_elapsed     | 2103     |
# |    total_timesteps  | 581309   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0383   |
# |    n_updates        | 120327   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 276      |
# |    time_elapsed     | 2109     |
# |    total_timesteps  | 582759   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 120689   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 276      |
# |    time_elapsed     | 2111     |
# |    total_timesteps  | 583491   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0462   |
# |    n_updates        | 120872   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 276      |
# |    time_elapsed     | 2114     |
# |    total_timesteps  | 584464   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 121115   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 276      |
# |    time_elapsed     | 2120     |
# |    total_timesteps  | 585949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 121487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 276      |
# |    time_elapsed     | 2123     |
# |    total_timesteps  | 586686   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 121671   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 276      |
# |    time_elapsed     | 2130     |
# |    total_timesteps  | 588706   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0732   |
# |    n_updates        | 122176   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 276      |
# |    time_elapsed     | 2133     |
# |    total_timesteps  | 589607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 122401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 454      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 276      |
# |    time_elapsed     | 2138     |
# |    total_timesteps  | 590979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 122744   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 454      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 276      |
# |    time_elapsed     | 2141     |
# |    total_timesteps  | 591715   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 122928   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 276      |
# |    time_elapsed     | 2145     |
# |    total_timesteps  | 592725   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 123181   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 276      |
# |    time_elapsed     | 2148     |
# |    total_timesteps  | 593710   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0475   |
# |    n_updates        | 123427   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 455      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 276      |
# |    time_elapsed     | 2153     |
# |    total_timesteps  | 595034   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00971  |
# |    n_updates        | 123758   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 454      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 276      |
# |    time_elapsed     | 2157     |
# |    total_timesteps  | 595887   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 123971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 276      |
# |    time_elapsed     | 2161     |
# |    total_timesteps  | 597064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0385   |
# |    n_updates        | 124265   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 276      |
# |    time_elapsed     | 2166     |
# |    total_timesteps  | 598611   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 124652   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 276      |
# |    time_elapsed     | 2170     |
# |    total_timesteps  | 599743   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 124935   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=487.00 +/- 52.78
# Episode length: 3586.80 +/- 554.57
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.59e+03 |
# |    mean_reward      | 487      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 275      |
# |    time_elapsed     | 2185     |
# |    total_timesteps  | 601185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 125296   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 275      |
# |    time_elapsed     | 2188     |
# |    total_timesteps  | 601919   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00889  |
# |    n_updates        | 125479   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 274      |
# |    time_elapsed     | 2193     |
# |    total_timesteps  | 603110   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 125777   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 275      |
# |    time_elapsed     | 2197     |
# |    total_timesteps  | 604495   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00833  |
# |    n_updates        | 126123   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 275      |
# |    time_elapsed     | 2201     |
# |    total_timesteps  | 605494   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 126373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 274      |
# |    time_elapsed     | 2205     |
# |    total_timesteps  | 606484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 126620   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 275      |
# |    time_elapsed     | 2210     |
# |    total_timesteps  | 607869   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 126967   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 275      |
# |    time_elapsed     | 2215     |
# |    total_timesteps  | 609304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.045    |
# |    n_updates        | 127325   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 274      |
# |    time_elapsed     | 2219     |
# |    total_timesteps  | 610189   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 127547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 274      |
# |    time_elapsed     | 2221     |
# |    total_timesteps  | 610920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 127729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 274      |
# |    time_elapsed     | 2228     |
# |    total_timesteps  | 612664   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 128165   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 274      |
# |    time_elapsed     | 2232     |
# |    total_timesteps  | 613787   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 128446   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 274      |
# |    time_elapsed     | 2235     |
# |    total_timesteps  | 614467   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 128616   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 274      |
# |    time_elapsed     | 2242     |
# |    total_timesteps  | 616265   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 129066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 274      |
# |    time_elapsed     | 2248     |
# |    total_timesteps  | 617933   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0609   |
# |    n_updates        | 129483   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 274      |
# |    time_elapsed     | 2251     |
# |    total_timesteps  | 618788   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 129696   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 274      |
# |    time_elapsed     | 2257     |
# |    total_timesteps  | 620458   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 130114   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 274      |
# |    time_elapsed     | 2260     |
# |    total_timesteps  | 621268   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 130316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 274      |
# |    time_elapsed     | 2266     |
# |    total_timesteps  | 622768   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0353   |
# |    n_updates        | 130691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 274      |
# |    time_elapsed     | 2269     |
# |    total_timesteps  | 623738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 130934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 274      |
# |    time_elapsed     | 2273     |
# |    total_timesteps  | 624811   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 131202   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=396.00 +/- 64.14
# Episode length: 3538.60 +/- 328.49
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.54e+03 |
# |    mean_reward      | 396      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 273      |
# |    time_elapsed     | 2286     |
# |    total_timesteps  | 625832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0614   |
# |    n_updates        | 131457   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 273      |
# |    time_elapsed     | 2291     |
# |    total_timesteps  | 626874   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 131718   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 273      |
# |    time_elapsed     | 2295     |
# |    total_timesteps  | 628228   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 132056   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 273      |
# |    time_elapsed     | 2298     |
# |    total_timesteps  | 629071   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 132267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 273      |
# |    time_elapsed     | 2305     |
# |    total_timesteps  | 630794   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 132698   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | 454      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 273      |
# |    time_elapsed     | 2310     |
# |    total_timesteps  | 632338   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 133084   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.37e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 273      |
# |    time_elapsed     | 2316     |
# |    total_timesteps  | 633806   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 133451   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.37e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 273      |
# |    time_elapsed     | 2319     |
# |    total_timesteps  | 634728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 133681   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 457      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 273      |
# |    time_elapsed     | 2324     |
# |    total_timesteps  | 636225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 134056   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 460      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 273      |
# |    time_elapsed     | 2331     |
# |    total_timesteps  | 637982   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 134495   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 462      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 273      |
# |    time_elapsed     | 2336     |
# |    total_timesteps  | 639405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 134851   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43e+03 |
# |    ep_rew_mean      | 465      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 273      |
# |    time_elapsed     | 2342     |
# |    total_timesteps  | 640966   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0275   |
# |    n_updates        | 135241   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.47e+03 |
# |    ep_rew_mean      | 472      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 273      |
# |    time_elapsed     | 2349     |
# |    total_timesteps  | 643131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 135782   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.47e+03 |
# |    ep_rew_mean      | 472      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 273      |
# |    time_elapsed     | 2353     |
# |    total_timesteps  | 644036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0309   |
# |    n_updates        | 136008   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.46e+03 |
# |    ep_rew_mean      | 473      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 273      |
# |    time_elapsed     | 2358     |
# |    total_timesteps  | 645483   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 136370   |
# ----------------------------------
# ----------------------------------
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 213235   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3724     |
# |    fps              | 262      |
# |    time_elapsed     | 3635     |
# |    total_timesteps  | 954279   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00792  |
# |    n_updates        | 213569   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3728     |
# |    fps              | 262      |
# |    time_elapsed     | 3644     |
# |    total_timesteps  | 956855   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 214213   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3732     |
# |    fps              | 262      |
# |    time_elapsed     | 3657     |
# |    total_timesteps  | 960317   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 215079   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3736     |
# |    fps              | 262      |
# |    time_elapsed     | 3661     |
# |    total_timesteps  | 961276   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 215318   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3740     |
# |    fps              | 262      |
# |    time_elapsed     | 3667     |
# |    total_timesteps  | 963090   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 215772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 607      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3744     |
# |    fps              | 262      |
# |    time_elapsed     | 3675     |
# |    total_timesteps  | 965072   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 216267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 607      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3748     |
# |    fps              | 262      |
# |    time_elapsed     | 3678     |
# |    total_timesteps  | 966000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.055    |
# |    n_updates        | 216499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3752     |
# |    fps              | 262      |
# |    time_elapsed     | 3683     |
# |    total_timesteps  | 967411   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 216852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 608      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3756     |
# |    fps              | 262      |
# |    time_elapsed     | 3690     |
# |    total_timesteps  | 969178   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 217294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3760     |
# |    fps              | 262      |
# |    time_elapsed     | 3696     |
# |    total_timesteps  | 970942   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 217735   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 608      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3764     |
# |    fps              | 262      |
# |    time_elapsed     | 3701     |
# |    total_timesteps  | 972027   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 218006   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 608      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3768     |
# |    fps              | 262      |
# |    time_elapsed     | 3705     |
# |    total_timesteps  | 973178   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 218294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3772     |
# |    fps              | 262      |
# |    time_elapsed     | 3710     |
# |    total_timesteps  | 974451   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 218612   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=601.00 +/- 177.78
# Episode length: 4679.40 +/- 642.06
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.68e+03 |
# |    mean_reward      | 601      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3776     |
# |    fps              | 261      |
# |    time_elapsed     | 3730     |
# |    total_timesteps  | 976293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 219073   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 609      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3780     |
# |    fps              | 261      |
# |    time_elapsed     | 3734     |
# |    total_timesteps  | 977307   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 219326   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 613      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3784     |
# |    fps              | 261      |
# |    time_elapsed     | 3742     |
# |    total_timesteps  | 979340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 219834   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 622      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3788     |
# |    fps              | 261      |
# |    time_elapsed     | 3752     |
# |    total_timesteps  | 981861   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 220465   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 620      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3792     |
# |    fps              | 261      |
# |    time_elapsed     | 3755     |
# |    total_timesteps  | 982889   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 220722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 623      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3796     |
# |    fps              | 261      |
# |    time_elapsed     | 3761     |
# |    total_timesteps  | 984406   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 221101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 622      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 261      |
# |    time_elapsed     | 3766     |
# |    total_timesteps  | 985855   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0091   |
# |    n_updates        | 221463   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 625      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3804     |
# |    fps              | 261      |
# |    time_elapsed     | 3775     |
# |    total_timesteps  | 987980   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 221994   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 630      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3808     |
# |    fps              | 261      |
# |    time_elapsed     | 3779     |
# |    total_timesteps  | 989338   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 222334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 633      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 261      |
# |    time_elapsed     | 3785     |
# |    total_timesteps  | 990914   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 222728   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 636      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 261      |
# |    time_elapsed     | 3789     |
# |    total_timesteps  | 991824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00912  |
# |    n_updates        | 222955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 633      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 261      |
# |    time_elapsed     | 3793     |
# |    total_timesteps  | 992961   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 223240   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 635      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 261      |
# |    time_elapsed     | 3803     |
# |    total_timesteps  | 995633   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 223908   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 641      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 261      |
# |    time_elapsed     | 3809     |
# |    total_timesteps  | 997179   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 224294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 641      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 261      |
# |    time_elapsed     | 3814     |
# |    total_timesteps  | 998382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 224595   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=932.00 +/- 328.00
# Episode length: 5232.60 +/- 1492.60
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 5.23e+03 |
# |    mean_reward      | 932      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# ---
#
# ## Evaluate

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2025-08-01 12:20:31.999020: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754050832.031410   25035 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754050832.042294   25035 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-01 12:20:32.073933: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 520.00
# Atari Episode Length 4185
# Atari Episode Score: 600.00
# Atari Episode Length 4467
# Atari Episode Score: 865.00
# Atari Episode Length 4455
# Atari Episode Score: 695.00
# Atari Episode Length 4137

# %% [markdown]
# ---

# %% [markdown]
# ## Upload to Hugging Face HUB

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga sbolanowski  -f logs/
# Out:
# 2025-08-01 12:32:52.655346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754051572.678420   28240 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754051572.684982   28240 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-01 12:32:52.705396: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to sbolanowski/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# args.yml: 1.27kB [00:00, 4.84MB/s]
#
# README.md: 2.82kB [00:00, 1.94MB/s]
#
# config.yml: 100% 549/549 [00:00<00:00, 4.13MB/s]
#
# .gitattributes: 1.56kB [00:00, 7.49MB/s]
# Fetching 14 files:   7% 1/14 [00:00<00:06,  1.89it/s]
# data: 205kB [00:00, 32.8MB/s]
#
# _stable_baselines3_version: 100% 5.00/5.00 [00:00<00:00, 48.4kB/s]
# Fetching 14 files:  43% 6/14 [00:00<00:00, 11.96it/s]
# env_kwargs.yml: 100% 23.0/23.0 [00:00<00:00, 235kB/s]
#
# results.json: 100% 153/153 [00:00<00:00, 1.69MB/s]
#
# system_info.txt: 100% 260/260 [00:00<00:00, 2.77MB/s]
# Fetching 14 files: 100% 14/14 [00:01<00:00, 13.09it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmp7b_5giif/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmp7b_5giif/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp7b_5giif/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp7b_5giif/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:00<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:00<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  62% 8.37M/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:00<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:00<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  62% 8.37M/13.5M [00:00<?, ?B/s]
#
#
#
#
# Processing Files (3 / 4)                :  40% 21.9M/54.3M [00:00<00:00, 97.1MB/s,   ???B/s  ]
#
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  99% 26.8M/27.2M [00:00<?, ?B/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:00<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:00<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<00:00, 25.8MB/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
# Processing Files (4 / 5)                :  99% 53.9M/54.3M [00:00<00:00, 133MB/s,  160MB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:00<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:00<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<00:00, 12.9MB/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  99% 26.8M/27.2M [00:00<?, ?B/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:00<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:00<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<00:00, 8.57MB/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  99% 26.8M/27.2M [00:00<?, ?B/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:00<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:00<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<00:00, 6.43MB/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
# Processing Files (5 / 5)                : 100% 54.3M/54.3M [00:01<00:00, 39.4MB/s, 40.4MB/s  ]
# New Data Upload                         : 100% 382k/382k [00:01<00:00, 373kB/s,  477kB/s  ]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:01<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:00<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<00:00, 5.14MB/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 477kB/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:01<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:01<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 4.30MB/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 384kB/s]
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:01<?, ?B/s]
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:01<?, ?B/s]
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 4.29MB/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
# Processing Files (5 / 5)                : 100% 54.3M/54.3M [00:01<00:00, 38.1MB/s, 27.0MB/s  ]
# New Data Upload                         : 100% 382k/382k [00:01<00:00, 268kB/s,  318kB/s  ]
#   ...oFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:01<?, ?B/s]
#   ...Frameskip-v4/train_eval_metrics.zip: 100% 36.0k/36.0k [00:01<?, ?B/s]
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<00:00, 4.28MB/s]
#   ...NoFrameskip-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 381kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/sbolanowski/dqn-SpaceInvadersNoFrameskip-v4
